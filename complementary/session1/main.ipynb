# %%
#!pip install stata_setup
import sys
print(sys.executable)
import stata_setup
stata_setup.config("C:\\Program Files\\StataNow19", "se")
# Out:
# c:\Users\maico\AppData\Local\Programs\Python\Python310\python.exe
#
#   ___  ____  ____  ____  ____ ®
#  /__    /   ____/   /   ____/      StataNow 19.5
# ___/   /   /___/   /   /___/       SE—Standard Edition
#
#  Statistics and Data Science       Copyright 1985-2025 StataCorp LLC
#                                    StataCorp
#                                    4905 Lakeway Drive
#                                    College Station, Texas 77845 USA
#                                    800-782-8272        https://www.stata.com
#                                    979-696-4600        service@stata.com
#
# Stata license: Unlimited-user network, expiring 16 Aug 2025
# Serial number: 401909309297
#   Licensed to: Mahicol Stiben Ramírez González
#                Universidad de los Andes
#
# Notes:
#       1. Unicode is supported; see help unicode_advice.
#       2. Maximum number of variables is set to 5,000 but can be increased;
#           see help set_maxvar.

# %%
# %%stata
# clear all
# cap log close
# set more off, perm
# #cls
# Out:
# . clear all
#
# . cap log close
#
# . set more off, perm
# (set more preference recorded)
#
# . #cls
# Unknown #command
# .

# %%
# %%stata
# if "`c(username)'"=="maico" {
# 	global path "C:\Users\maico\Documents\2025\GitHub\Advanced-Economemtrics\complementary\session1"
# 		}
# 	if "`c(username)'"=="maico" {
# 	global path "_______________RUTA__________"
# 		}
#
# 	cd "$path"
#
# 	* En qué directorio estamos trabajando
# 	pwd
#
# 	* Archivos en el directorio
# 	dir
# Out:
# . if "`c(username)'"=="maico" {
# .         global path "C:\Users\maico\Documents\2025\GitHub\Advanced-Economemtr
# > ics\complementary\session1"
# .                 }
#
# .         if "`c(username)'"=="maico" {
# .         global path "_______________RUTA__________"
# .                 }
#
# .
# .         cd "$path"
# unable to change to _______________RUTA__________
# r(170);
# r(170);
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 get_ipython().run_cell_magic('stata', '', 'if "`c(username)\'"=="maico" {\n\tglobal path "C:\\Users\\maico\\Documents\\2025\\GitHub\\Advanced-Economemtrics\\complementary\\session1"\n\t\t}\n\tif "`c(username)\'"=="maico" {\n\tglobal path "_______________RUTA__________"\n\t\t}\n\n\tcd "$path"\n\n\t* En qué directorio estamos trabajando\t\n\tpwd\n\t\t\n\t* Archivos en el directorio\n\tdir\n')
#
# ...
